# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #Data Preprocessing

# %%
df_data = pd.read_csv('garments_worker_productivity.csv')

# %%
df_data.head(5)
# Out:
#        date   quarter  department       day  team  targeted_productivity  \
# 0  1/1/2015  Quarter1      sweing  Thursday     8                   0.80
# 1  1/1/2015  Quarter1  finishing   Thursday     1                   0.75
# 2  1/1/2015  Quarter1      sweing  Thursday    11                   0.80
# 3  1/1/2015  Quarter1      sweing  Thursday    12                   0.80
# 4  1/1/2015  Quarter1      sweing  Thursday     6                   0.80
#
#      smv     wip  over_time  incentive  idle_time  idle_men  \
# 0  26.16  1108.0       7080         98        0.0         0
# 1   3.94     NaN        960          0        0.0         0
# 2  11.41   968.0       3660         50        0.0         0
# 3  11.41   968.0       3660         50        0.0         0
# 4  25.90  1170.0       1920         50        0.0         0
#
#    no_of_style_change  no_of_workers  actual_productivity
# 0                   0           59.0             0.940725
# ...

# %%
df_data
# Out:
#            date   quarter  department        day  team  targeted_productivity  \
# 0      1/1/2015  Quarter1      sweing   Thursday     8                   0.80
# 1      1/1/2015  Quarter1  finishing    Thursday     1                   0.75
# 2      1/1/2015  Quarter1      sweing   Thursday    11                   0.80
# 3      1/1/2015  Quarter1      sweing   Thursday    12                   0.80
# 4      1/1/2015  Quarter1      sweing   Thursday     6                   0.80
# ...         ...       ...         ...        ...   ...                    ...
# 1192  3/11/2015  Quarter2   finishing  Wednesday    10                   0.75
# 1193  3/11/2015  Quarter2   finishing  Wednesday     8                   0.70
# 1194  3/11/2015  Quarter2   finishing  Wednesday     7                   0.65
# 1195  3/11/2015  Quarter2   finishing  Wednesday     9                   0.75
# 1196  3/11/2015  Quarter2   finishing  Wednesday     6                   0.70
#
# ...

# %%
df_data.isnull().sum()
# Out:
# date                       0
# quarter                    0
# department                 0
# day                        0
# team                       0
# targeted_productivity      0
# smv                        0
# wip                      506
# over_time                  0
# incentive                  0
# idle_time                  0
# idle_men                   0
# no_of_style_change         0
# no_of_workers              0
# actual_productivity        0
# dtype: int64

# %%
df_data['wip'].fillna(df_data['wip'].mean(), inplace = True)

# %%
df_data.isnull().sum()
# Out:
# date                     0
# quarter                  0
# department               0
# day                      0
# team                     0
# targeted_productivity    0
# smv                      0
# wip                      0
# over_time                0
# incentive                0
# idle_time                0
# idle_men                 0
# no_of_style_change       0
# no_of_workers            0
# actual_productivity      0
# dtype: int64

# %%
df_data.describe()
# Out:
#               team  targeted_productivity          smv           wip  \
# count  1197.000000            1197.000000  1197.000000   1197.000000
# mean      6.426901               0.729632    15.062172   1190.465991
# std       3.463963               0.097891    10.943219   1395.647261
# min       1.000000               0.070000     2.900000      7.000000
# 25%       3.000000               0.700000     3.940000    970.000000
# 50%       6.000000               0.750000    15.260000   1190.465991
# 75%       9.000000               0.800000    24.260000   1190.465991
# max      12.000000               0.800000    54.560000  23122.000000
#
#           over_time    incentive    idle_time     idle_men  \
# count   1197.000000  1197.000000  1197.000000  1197.000000
# mean    4567.460317    38.210526     0.730159     0.369256
# std     3348.823563   160.182643    12.709757     3.268987
# min        0.000000     0.000000     0.000000     0.000000
# ...

# %% [markdown]
# Data Preprocessing
#
# Membagi data kedalam 2 klasifikasi dengan membandingkan data dengan rata-rata dari variable 'actual_productivity' Jika variabel 'actual_productivity' lebih besar dari rata-ratanya maka kita input variabel sebagai 1 Jika lebih kecil maka input sebagai 0.
#
# 0 & 1 ini adalah perbandingan apakah produktivitas sebenarnya sesuai dengan ekspetasi yang ada.

# %%
f = lambda x : 1 if x>= df_data['actual_productivity'].mean() else 0

# %%
df_data['effective'] = df_data['actual_productivity'].map(f)

# %%
df_data
# Out:
#            date   quarter  department        day  team  targeted_productivity  \
# 0      1/1/2015  Quarter1      sweing   Thursday     8                   0.80
# 1      1/1/2015  Quarter1  finishing    Thursday     1                   0.75
# 2      1/1/2015  Quarter1      sweing   Thursday    11                   0.80
# 3      1/1/2015  Quarter1      sweing   Thursday    12                   0.80
# 4      1/1/2015  Quarter1      sweing   Thursday     6                   0.80
# ...         ...       ...         ...        ...   ...                    ...
# 1192  3/11/2015  Quarter2   finishing  Wednesday    10                   0.75
# 1193  3/11/2015  Quarter2   finishing  Wednesday     8                   0.70
# 1194  3/11/2015  Quarter2   finishing  Wednesday     7                   0.65
# 1195  3/11/2015  Quarter2   finishing  Wednesday     9                   0.75
# 1196  3/11/2015  Quarter2   finishing  Wednesday     6                   0.70
#
# ...

# %%
df_target = df_data[df_data['effective']==0]

# %%
qq = df_target[['department','effective']]

# %%
qqq = qq.groupby(['department']).agg({'effective':'count'}).reset_index()

# %%
qqq
# Out:
#    department  effective
# 0   finishing        112
# 1  finishing          86
# 2      sweing        276

# %%
sns.barplot(x = 'department', y='effective', data=qqq)

# %%
df_data.groupby(['department']).agg({'targeted_productivity':'sum'}).reset_index().rename(columns = {'actual_productivity':'Total Productivity'})
# Out:
#    department  targeted_productivity
# 0   finishing                 182.10
# 1  finishing                  191.00
# 2      sweing                 500.27

# %%
df_data.groupby(['quarter']).agg({'actual_productivity':'sum'}).reset_index().rename(columns = {'actual_productivity':'Total Productivity'})
# Out:
#     quarter  Total Productivity
# 0  Quarter1          270.561521
# 1  Quarter2          249.142761
# 2  Quarter3          147.999310
# 3  Quarter4          175.848647
# 4  Quarter5           36.351805

# %%
from sklearn.preprocessing import LabelEncoder
cols = ('quarter', 'department', 'day')
for i in cols:
    lbl = LabelEncoder()
    lbl.fit(list(df_data[i].values))
    df_data[i] = lbl.transform(list(df_data[i].values))

# %%
df_data.head(5)
# Out:
#        date  quarter  department  day  team  targeted_productivity    smv  \
# 0  1/1/2015        0           2    3     8                   0.80  26.16
# 1  1/1/2015        0           1    3     1                   0.75   3.94
# 2  1/1/2015        0           2    3    11                   0.80  11.41
# 3  1/1/2015        0           2    3    12                   0.80  11.41
# 4  1/1/2015        0           2    3     6                   0.80  25.90
#
#            wip  over_time  incentive  idle_time  idle_men  no_of_style_change  \
# 0  1108.000000       7080         98        0.0         0                   0
# 1  1190.465991        960          0        0.0         0                   0
# 2   968.000000       3660         50        0.0         0                   0
# 3   968.000000       3660         50        0.0         0                   0
# 4  1170.000000       1920         50        0.0         0                   0
#
#    no_of_workers  actual_productivity  effective
# ...

# %% [markdown]
# #EDA

# %%
df_data.hist(figsize=(15,15), bins = 30, color = '#29AF7F')
plt.show()

# %%
plt.figure(figsize=(12,14))
sns.heatmap(df_data.corr(), cmap = 'coolwarm', annot = True, linewidth=2)
plt.show()

# %%
sns.catplot(x = 'targeted_productivity', y = 'actual_productivity', data=df_data);

# %% [markdown]
# Berdasarkan boxplot diatas, dapat kita simpulkan bahwa tidak semua target produksi dapat terpenuhi, kita tambah variable baru perbandingan dari target yang ditentukan dengan aktual target yang diperoleh.

# %%
df_data['target'] = np.where(df_data['actual_productivity'] >= df_data['targeted_productivity'], 1, 0 )
df_data.head(5)
# Out:
#        date  quarter  department  day  team  targeted_productivity    smv  \
# 0  1/1/2015        0           2    3     8                   0.80  26.16
# 1  1/1/2015        0           1    3     1                   0.75   3.94
# 2  1/1/2015        0           2    3    11                   0.80  11.41
# 3  1/1/2015        0           2    3    12                   0.80  11.41
# 4  1/1/2015        0           2    3     6                   0.80  25.90
#
#            wip  over_time  incentive  idle_time  idle_men  no_of_style_change  \
# 0  1108.000000       7080         98        0.0         0                   0
# 1  1190.465991        960          0        0.0         0                   0
# 2   968.000000       3660         50        0.0         0                   0
# 3   968.000000       3660         50        0.0         0                   0
# 4  1170.000000       1920         50        0.0         0                   0
#
# ...

# %%
df_data.head(3)
# Out:
#        date  quarter  department  day  team  targeted_productivity    smv  \
# 0  1/1/2015        0           2    3     8                   0.80  26.16
# 1  1/1/2015        0           1    3     1                   0.75   3.94
# 2  1/1/2015        0           2    3    11                   0.80  11.41
#
#            wip  over_time  incentive  idle_time  idle_men  no_of_style_change  \
# 0  1108.000000       7080         98        0.0         0                   0
# 1  1190.465991        960          0        0.0         0                   0
# 2   968.000000       3660         50        0.0         0                   0
#
#    no_of_workers  actual_productivity  effective  target
# 0           59.0             0.940725          1       1
# 1            8.0             0.886500          1       1
# 2           30.5             0.800570          1       1

# %%
sns.set()
cols = ['targeted_productivity', 'smv', 'wip', 'over_time', 'incentive', 'no_of_workers','idle_time', 'idle_men', 'no_of_style_change' ]
sns.pairplot(df_data[cols], size=2.5, palette = 'viridis')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df_data
# Out:
#            date  quarter  department  day  team  targeted_productivity    smv  \
# 0      1/1/2015        0           2    3     8                   0.80  26.16
# 1      1/1/2015        0           1    3     1                   0.75   3.94
# 2      1/1/2015        0           2    3    11                   0.80  11.41
# 3      1/1/2015        0           2    3    12                   0.80  11.41
# 4      1/1/2015        0           2    3     6                   0.80  25.90
# ...         ...      ...         ...  ...   ...                    ...    ...
# 1192  3/11/2015        1           0    5    10                   0.75   2.90
# 1193  3/11/2015        1           0    5     8                   0.70   3.90
# 1194  3/11/2015        1           0    5     7                   0.65   3.90
# 1195  3/11/2015        1           0    5     9                   0.75   2.90
# 1196  3/11/2015        1           0    5     6                   0.70   2.90
#
# ...

# %%
df_data['target'].value_counts().reset_index()
# Out:
#    index  target
# 0      1     875
# 1      0     322

# %%
#proportion of Target

explore_target = df_data['target'].value_counts()
label = 'reach the target', 'did not reach the target'
explode = (0, 0.1)
plt.pie(explore_target,
       labels = label,
        autopct='%1.1f%%',
       explode=explode)
plt.title('Proportion of Target', size = 14)
plt.show()

# %% [markdown]
# Our data has an imbalance proportion, the proportion who reach the target is much higher than those who did not reach the target

# %% [markdown]
# # Train-Test Split

# %%
X = df_data[cols]
y = df_data['target']

# %%
# split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state = 45)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# agar splitting tidak berubah, diberi random_state
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 45)
# Out:
# (897, 9) (300, 9) (897,) (300,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=X.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X.columns)

# %%
X_train_scaled.head(2)
# Out:
#    targeted_productivity       smv       wip  over_time  incentive  \
# 0               0.712472 -0.331414 -0.472378  -0.341585   0.064322
# 1               0.712472 -0.949279 -0.022905   1.749582  -0.252835
#
#    no_of_workers  idle_time  idle_men  no_of_style_change
# 0       1.049798  -0.056093 -0.097915           -0.338401
# 1      -0.436443  -0.056093 -0.097915           -0.338401

# %%
X_test_scaled.head(2)
# Out:
#    targeted_productivity       smv       wip  over_time  incentive  \
# 0              -0.746220  0.536179 -0.221539   0.786184   0.285453
# 1               0.244338  0.698072 -0.860847   1.714912   0.363216
#
#    no_of_workers  idle_time  idle_men  no_of_style_change
# 0       1.112492  -0.069218 -0.151071           -0.389759
# 1       0.976996  -0.069218 -0.151071           -0.389759

# %% [markdown]
# # Classification Model

# %%
from sklearn.neighbors import KNeighborsClassifier #KNN
from sklearn.tree import DecisionTreeClassifier #Decision Tree
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn.metrics import confusion_matrix

# %%
#Evaluation Matrix
def classification_eval (aktual, prediksi, name):
    cm = confusion_matrix(aktual, prediksi)
    tp = cm[1][1]
    tn = cm[0][0]
    fp = cm[0][1]
    fn = cm[1][0]
    
    accuracy = round((tp+tn) / (tp+tn+fp+fn) * 100, 2)
    precision = round((tp) / (tp+fp) * 100,2)
    recall = round((tp) / (tp+fn) * 100,2)
    f1_score = 2*(precision * recall) / (precision+recall)
    
    print('Evaluation Model', name)
    print(cm)
    print('Accuracy :', accuracy, '%')
    print('Precision :', precision, '%')
    print('Recall :', recall, '%')
    print('F1_Score :', f1_score)

# %% [markdown]
# # KNN

# %%
error_rate = []
# Will take some time
for i in range(1,20):
 
 knn = KNeighborsClassifier(n_neighbors=i)
 knn.fit(X_train,y_train)
 pred_i = knn.predict(X_test)
 error_rate.append(np.mean(pred_i != y_test))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.plot(range(1,20),error_rate,color='blue', linestyle='dashed', marker='o',
 markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
knn = KNeighborsClassifier(n_neighbors=6)
knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %%
y_train_pred = knn.predict(X_train_scaled)
y_test_pred = knn.predict(X_test_scaled)

# %%
classification_eval(y_train, y_train_pred, 'KNN Training')
# Out:
# Evaluation Model KNN Training
# [[140  86]
#  [ 63 608]]
# Accuracy : 83.39 %
# Precision : 87.61 %
# Recall : 90.61 %
# F1_Score : 89.08475030860734

# %%
classification_eval(y_test, y_test_pred, 'KNN Testing')
# Out:
# Evaluation Model KNN Testing
# [[ 51  45]
#  [ 20 184]]
# Accuracy : 78.33 %
# Precision : 80.35 %
# Recall : 90.2 %
# F1_Score : 84.99055995309293

# %% [markdown]
# # Decision Tree

# %%
from sklearn.metrics import roc_curve, auc

max_depths = np.linspace(1, 32, 32, endpoint=True)
train_results = []
test_results = []
for max_depth in max_depths:
   dt = DecisionTreeClassifier(max_depth=max_depth)
   dt.fit(X_train, y_train)
   train_pred = dt.predict(X_train)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train, train_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   # Add auc score to previous train results
   train_results.append(roc_auc)
   y_pred = dt.predict(X_test)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   # Add auc score to previous test results
   test_results.append(roc_auc)
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(max_depths, train_results, 'b', label='Train AUC')
line2, = plt.plot(max_depths, test_results, 'r', label='Test AUC')
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('AUC score')
plt.xlabel('Tree depth')
plt.show()

# %%
dectree = DecisionTreeClassifier(max_depth=2)
dectree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
y_train_pred = dectree.predict(X_train)
y_test_pred = dectree.predict(X_test)

# %%
classification_eval(y_train, y_train_pred, 'Decision Tree Testing')
# Out:
# Evaluation Model Decision Tree Testing
# [[ 63 163]
#  [ 29 642]]
# Accuracy : 78.6 %
# Precision : 79.75 %
# Recall : 95.68 %
# F1_Score : 86.99173459499515

# %%
classification_eval(y_test, y_test_pred, 'Decision Tree Testing')
# Out:
# Evaluation Model Decision Tree Testing
# [[ 24  72]
#  [  3 201]]
# Accuracy : 75.0 %
# Precision : 73.63 %
# Recall : 98.53 %
# F1_Score : 84.27932039962825

# %% [markdown]
# #Random Forest

# %%
ranfor = RandomForestClassifier(max_depth=8)
ranfor.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=8)

# %%
y_train_pred = ranfor.predict(X_train)
y_test_pred = ranfor.predict(X_test)

# %%
classification_eval(y_train, y_train_pred, 'Random Forest Training')
# Out:
# Evaluation Model Random Forest Training
# [[141  85]
#  [ 14 657]]
# Accuracy : 88.96 %
# Precision : 88.54 %
# Recall : 97.91 %
# F1_Score : 92.98955644945026

# %%
classification_eval(y_test, y_test_pred, 'Random Forest testing')
# Out:
# Evaluation Model Random Forest testing
# [[ 50  46]
#  [  9 195]]
# Accuracy : 81.67 %
# Precision : 80.91 %
# Recall : 95.59 %
# F1_Score : 87.63951161473088

# %%
#from sklearn.svm import SVC
#classifier = SVC(kernel = 'linear', random_state = 0, decision_function_shape='ovr')
#classifier.fit(X_train, y_train)

# %% [markdown]
# #Handling imbalance Data with SMOTE

# %%
pip install shap
# Out:
# ...
#      |████████████████████████████████| 564 kB 18.3 MB/s
# ...

# %%
import shap
from imblearn.over_sampling import SMOTE
smote = SMOTE()
x_resample, y_resample = smote.fit_resample(X_train, y_train.ravel())
Xr_train, Xr_test, yr_train, yr_test = train_test_split(x_resample, y_resample, test_size = 0.25, random_state=1)
print(Xr_train.shape, Xr_test.shape, yr_train.shape, yr_test.shape)
# Out:
# (1006, 9) (336, 9) (1006,) (336,)

# %%
#Scaling data smote
Xr_train_scaled = scaler.fit_transform(Xr_train)
Xr_test_scaled = scaler.transform(Xr_test)

Xr_train_scaled = pd.DataFrame(Xr_train_scaled, columns = X.columns)
Xr_test_scaled = pd.DataFrame(Xr_test_scaled, columns = X.columns)

# %%
ranfor_ = RandomForestClassifier(max_depth=8)
ranfor_.fit(Xr_train_scaled, yr_train)
# Out:
# RandomForestClassifier(max_depth=8)

# %%
y_train_pred = ranfor_.predict(Xr_train_scaled)
y_test_pred = ranfor_.predict(Xr_test_scaled)

# %%
classification_eval(yr_train, y_train_pred, 'Random Forest Training')
# Out:
# Evaluation Model Random Forest Training
# [[469  26]
#  [ 50 461]]
# Accuracy : 92.45 %
# Precision : 94.66 %
# Recall : 90.22 %
# F1_Score : 92.38668541756815

# %%
classification_eval(yr_test, y_test_pred, 'Random Forest testing')
# Out:
# Evaluation Model Random Forest testing
# [[150  26]
#  [ 20 140]]
# Accuracy : 86.31 %
# Precision : 84.34 %
# Recall : 87.5 %
# F1_Score : 85.89094506517691

# %% [markdown]
# #Feature Importance

# %%
importances = ranfor_.feature_importances_
indices = np.argsort(importances)

fig, ax = plt.subplots()
ax.barh(range(len(importances)), importances[indices])
ax.set_yticks(range(len(importances)))
_ = ax.set_yticklabels(np.array(X_train.columns)[indices])

# %% [markdown]
# #Training

# %%
#Pemanfaatan Trained Model
#targeted_productivity', 'smv', 'wip', 'over_time', 'incentive', 'no_of_workers','idle_time', 'idle_men', 'no_of_style_change
data_baru = [[0.90,10,1108,2000,100,50,0,0,0],
             [0.90,10,1108,2000,50,50,0,0,0]]
preds = ranfor_.predict(data_baru)
preds
# Out:
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# array([1, 1])
